# %% [markdown]
# ## CNN 스팸 메일 분류

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
# 데이터 로드, 전처리
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# * https://raw.githubusercontent.com/mohitgupta-omg/Kaggle-SMS-Spam-Collection-Dataset-/master/spam.csv

# %%
import urllib.request

urllib.request.urlretrieve('https://raw.githubusercontent.com/mohitgupta-omg/Kaggle-SMS-Spam-Collection-Dataset-/master/spam.csv', filename='spam.csv')
data = pd.read_csv('spam.csv', encoding='latin-1')
print(len(data)) # 5572
# Out:
# 5572

# %%
data
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
del data['Unnamed: 2']
del data['Unnamed: 3']
del data['Unnamed: 4']
data['v1'] = data['v1'].replace(['ham', 'spam'], [0, 1])
data[:10]
# Out:
#    v1                                                 v2
# 0   0  Go until jurong point, crazy.. Available only ...
# 1   0                      Ok lar... Joking wif u oni...
# 2   1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   0  U dun say so early hor... U c already then say...
# 4   0  Nah I don't think he goes to usf, he lives aro...
# 5   1  FreeMsg Hey there darling it's been 3 week's n...
# 6   0  Even my brother is not like to speak with me. ...
# 7   0  As per your request 'Melle Melle (Oru Minnamin...
# 8   1  WINNER!! As a valued network customer you have...
# 9   1  Had your mobile 11 months or more? U R entitle...

# %%
data.drop_duplicates(subset=['v2'], inplace=True)
len(data) # 5169개로 줄어듦
# Out:
# 5169

# %%
data['v1'].value_counts().plot(kind='bar'); # 정상메일이 스팸보다 많음

# %%
data.groupby('v1').size().reset_index(name = 'count')
# Out:
#    v1  count
# 0   0   4516
# 1   1    653

# %%
X_data = data['v2']
y_data = data['v1']

# %%
vocab_size = 1000
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(X_data) # 토큰화
sequences = tokenizer.texts_to_sequences(X_data) # 토큰에 인덱스 추가

# %%
print(sequences[:2])
# Out:
# [[47, 433, 780, 705, 662, 64, 8, 94, 121, 434, 142, 68, 57, 137], [49, 306, 435, 6]]

# %%
X_data = sequences

print('메일 최대 길이 : {}'.format(max(len(l) for l in X_data)))
print('메일 평균 길이 : {}'.format(sum(map(len, X_data))/len(X_data)))
# 메일 최대 길이 : 172
# 메일 평균 길이 : 12.566840781582512
# Out:
# 메일 최대 길이 : 172
# 메일 평균 길이 : 12.566840781582512

# %%
plt.hist([len(s) for s in X_data], bins = 50)
plt.xlabel('Length of Samples')
plt.ylabel('Number of Samples')
plt.show()

# %%
# 위 히스토그램 -> 60이상의 단어는 제거해도 무방
max_len = 60
data = pad_sequences(X_data, maxlen = max_len)
print(data.shape)
# Out:
# (5169, 60)

# %%
n_train = int(len(sequences) * 0.8)
n_test = int(len(sequences) - n_train)

print(n_train)
print(n_test)
# Out:
# 4135
# 1034

# %%
X_train = data[:n_train]
y_train = np.array(y_data[:n_train])
X_test = data[n_train:]
y_test = np.array(y_data[n_train:])

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (4135, 60)
# (4135,)
# (1034, 60)
# (1034,)

# %% [markdown]
# ### 모델 구성

# %%
from tensorflow.keras.layers import Dense, Conv1D, GlobalMaxPooling1D, Embedding,Dropout, MaxPooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()
model.add(Embedding(vocab_size, 32))
model.add(Dropout(0.2))
model.add(Conv1D(32, 5, strides=1, padding='valid', activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.summary()

model.compile(optimizer = 'adam', loss='binary_crossentropy', metrics=['acc'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 32)          32000
#
#  dropout (Dropout)           (None, None, 32)          0
#
#  conv1d (Conv1D)             (None, None, 32)          5152
#
#  global_max_pooling1d (Globa  (None, 32)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 39,329
# Trainable params: 39,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
# earlystopping, checkpoints
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode = 'max', verbose=1, save_best_only=True)

# %% [markdown]
# ### 모델 학습

# %%
history = model.fit(X_train, y_train, epochs = 10, batch_size=64, validation_split=0.2, callbacks=[es, mc])
# Out:
# Epoch 1/10
# 52/52 [==============================] - ETA: 0s - loss: 0.4805 - acc: 0.8540
# Epoch 1: val_acc improved from -inf to 0.87304, saving model to best_model.h5
# 52/52 [==============================] - 15s 13ms/step - loss: 0.4805 - acc: 0.8540 - val_loss: 0.3773 - val_acc: 0.8730
# Epoch 2/10
# 49/52 [===========================>..] - ETA: 0s - loss: 0.3482 - acc: 0.8699
# Epoch 2: val_acc did not improve from 0.87304
# 52/52 [==============================] - 0s 6ms/step - loss: 0.3436 - acc: 0.8697 - val_loss: 0.2608 - val_acc: 0.8730
# Epoch 3/10
# 48/52 [==========================>...] - ETA: 0s - loss: 0.1411 - acc: 0.9469
# Epoch 3: val_acc improved from 0.87304 to 0.98307, saving model to best_model.h5
# 52/52 [==============================] - 0s 6ms/step - loss: 0.1380 - acc: 0.9483 - val_loss: 0.0630 - val_acc: 0.9831
# Epoch 4/10
# 51/52 [============================>.] - ETA: 0s - loss: 0.0509 - acc: 0.9868
# Epoch 4: val_acc did not improve from 0.98307
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0504 - acc: 0.9870 - val_loss: 0.0493 - val_acc: 0.9807
# Epoch 5/10
# 51/52 [============================>.] - ETA: 0s - loss: 0.0304 - acc: 0.9908
# Epoch 5: val_acc did not improve from 0.98307
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0311 - acc: 0.9906 - val_loss: 0.0487 - val_acc: 0.9807
# Epoch 6/10
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0216 - acc: 0.9952
# Epoch 6: val_acc did not improve from 0.98307
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0208 - acc: 0.9955 - val_loss: 0.0477 - val_acc: 0.9831
# Epoch 7/10
# 51/52 [============================>.] - ETA: 0s - loss: 0.0142 - acc: 0.9972
# Epoch 7: val_acc did not improve from 0.98307
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0141 - acc: 0.9973 - val_loss: 0.0472 - val_acc: 0.9807
# Epoch 8/10
# 51/52 [============================>.] - ETA: 0s - loss: 0.0107 - acc: 0.9985
# Epoch 8: val_acc did not improve from 0.98307
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0106 - acc: 0.9985 - val_loss: 0.0484 - val_acc: 0.9807
# Epoch 9/10
# 49/52 [===========================>..] - ETA: 0s - loss: 0.0080 - acc: 0.9990
# Epoch 9: val_acc did not improve from 0.98307
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0078 - acc: 0.9991 - val_loss: 0.0480 - val_acc: 0.9794
# Epoch 10/10
# 52/52 [==============================] - ETA: 0s - loss: 0.0059 - acc: 0.9994
# Epoch 10: val_acc did not improve from 0.98307
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0059 - acc: 0.9994 - val_loss: 0.0504 - val_acc: 0.9807
# Epoch 10: early stopping

# %% [markdown]
# ### 시각화

# %%
# 시각화
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['acc']
val_acc = history.history['val_acc']

epochs = range(1, len(loss)+1)

plt.plot(epochs, loss, 'b--', label = 'training loss')
plt.plot(epochs, val_loss, 'r:', label='validation loss')
plt.grid()
plt.legend()

plt.figure()
plt.plot(epochs, acc, 'b--', label = 'training accuracy')
plt.plot(epochs, val_acc, 'r:', label='validation accuracy')
plt.grid()
plt.legend()

plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0697 - acc: 0.9807
# [0.06969021260738373, 0.9806576371192932]
